# %% [markdown]
# <a href="https://colab.research.google.com/github/hliu71/citation_function_classification/blob/main/Reference%26Citation_Similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ref 
# Sentence Similarity With BERT | Towards Data Science
# https://towardsdatascience.com/bert-for-measuring-text-similarity-eec91c6bf9e1

# %%
# !pip install sentence_transformers

# %%
sentences = [
    "Three years later, the coffin was still full of Jello.",
    "The fish dreamed of escaping the fishbowl and into the toilet where he saw his friend go.",
    "The person box was packed with jelly many dozens of months later.",
    "He found a leprechaun in his walnut shell.",
    "Three years later, the coffin was still full of Jello.",
]

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 46.1 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 39.8 MB/s
# ...
#      |████████████████████████████████| 120 kB 57.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 33.4 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=e6eca13a08b02a3028e0b00fea786fb467176628773d4081868b1ce1b093d37d
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
sentence_embeddings = model.encode(sentences)

# %%
sentence_embeddings.shape
# Out:
# (5, 768)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(
    [sentence_embeddings[0]],
    sentence_embeddings[1:]
)
# Out:
# array([[0.33088914, 0.72192585, 0.5548363 , 1.0000001 ]], dtype=float32)

# %%
sentences_1 = ['good to see you', 'good morning', 'nice to meet']

# %%
sentence_embeddings = model.encode(sentences_1)

# %%
sentence_embeddings.shape
# Out:
# (3, 768)

# %%
cosine_similarity(
    [sentence_embeddings[0]],
    sentence_embeddings[1:]
)
# Out:
# array([[0.69983685, 0.93500215]], dtype=float32)
